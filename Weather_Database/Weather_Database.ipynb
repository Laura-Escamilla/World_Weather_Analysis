# %% [markdown]
# # Weather Py

# %%
# Import dependencies

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Generating Random Latitudes and Longitudes

# %%
# Create new set of 2,000 random latitudes and logitudes
# Create a set of random latitude and longitude combinations

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

#Unpack the lat_lngs zip object into a list. This way, we only need to create a set of random latitudes and longitudes once.

lat_lngs = zip(lats, lngs)
lat_lngs

# %% [markdown]
# ## Generating Random World Cities

# %%
# Use the citipy module to determine city based on latitude and longitude

from citipy import citipy

# %%
# Get the nearest city using the citipy module
# Create a list for holding the cities.

cities = []

# Identify nearest city for each latitude and longitude combination

for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 760

# %% [markdown]
# ## Making an API Call

# %%
# Import the requests library
import requests

# Import the API key
from config import weather_api_key

# %%
# Perform an API call with the OpenWeatherMap

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Getting the Cities Weather Data

# %%
# Import the time library and the datetime module from the datetime library.

import time
from datetime import datetime

# %%
# Retrieve the following information from the API call:
# Latitude and longitude
# Mamimum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky)

# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        description = city_weather['weather'][0]['description']
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S') 

        # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":description,
                          "Date": city_date })

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | aquiraz
# Processing Record 2 of Set 1 | yellowknife
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | champerico
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | faanui
# Processing Record 8 of Set 1 | verkhnyaya toyma
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | port alfred
# Processing Record 11 of Set 1 | lebu
# Processing Record 12 of Set 1 | santa maria da boa vista
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | jamestown
# Processing Record 15 of Set 1 | georgetown
# Processing Record 16 of Set 1 | stornoway
# Processing Record 17 of Set 1 | ichinohe
# Processing Record 18 of Set 1 | cape town
# Processing Record 19 of Set 1 | tingrela
# City not found. Skipping...
# Processing Record 20 of Set 1 | puerto carreno
# Processing Record 21 of Set 1 | luderitz
# Processing Record 22 of Set 1 | acapulco
# Processing Record 23 of Set 1 | dikson
# Processing Record 24 of Set 1 | kampil
# Processing Record 25 of Set 1 | khandyga
# Processing Record 26 of Set 1 | kaltasy
# Processing Record 27 of Set 1 | caravelas
# Processing Record 28 of Set 1 | east london
# Processing Record 29 of Set 1 | talnakh
# Processing Record 30 of Set 1 | jalu
# Processing Record 31 of Set 1 | polson
# Processing Record 32 of Set 1 | hobart
# Processing Record 33 of Set 1 | pyapon
# Processing Record 34 of Set 1 | severo-kurilsk
# Processing Record 35 of Set 1 | saint george
# Processing Record 36 of Set 1 | chuy
# Processing Record 37 of Set 1 | khatanga
# Processing Record 38 of Set 1 | hilo
# Processing Record 39 of Set 1 | lapeer
# Processing Record 40 of Set 1 | saskylakh
# Processing Record 41 of Set 1 | konstantinovka
# Processing Record 42 of Set 1 | adrar
# Processing Record 43 of Set 1 | bethanien
# Processing Record 44 of Set 1 | abha
# Processing Record 45 of Set 1 | mahebourg
# Processing Record 46 of Set 1 | vaini
# Processing Record 47 of Set 1 | salta
# Processing Record 48 of Set 1 | pulaski
# Processing Record 49 of Set 1 | svetlogorsk
# Processing Record 50 of Set 1 | tuatapere
# Processing Record 1 of Set 2 | provideniya
# Processing Record 2 of Set 2 | ilulissat
# Processing Record 3 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 2 | yumen
# Processing Record 5 of Set 2 | lewisville
# Processing Record 6 of Set 2 | bluff
# Processing Record 7 of Set 2 | chokurdakh
# Processing Record 8 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 2 | kambam
# Processing Record 10 of Set 2 | sokode
# Processing Record 11 of Set 2 | panuco
# Processing Record 12 of Set 2 | fort nelson
# Processing Record 13 of Set 2 | eyl
# Processing Record 14 of Set 2 | kantang
# Processing Record 15 of Set 2 | hermanus
# Processing Record 16 of Set 2 | hithadhoo
# Processing Record 17 of Set 2 | dondo
# Processing Record 18 of Set 2 | atuona
# Processing Record 19 of Set 2 | harper
# Processing Record 20 of Set 2 | kapaa
# Processing Record 21 of Set 2 | salalah
# Processing Record 22 of Set 2 | evensk
# Processing Record 23 of Set 2 | lorengau
# Processing Record 24 of Set 2 | manokwari
# Processing Record 25 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 2 | nikki
# Processing Record 27 of Set 2 | lang son
# Processing Record 28 of Set 2 | songjianghe
# Processing Record 29 of Set 2 | kahului
# Processing Record 30 of Set 2 | andenes
# Processing Record 31 of Set 2 | new norfolk
# Processing Record 32 of Set 2 | qaanaaq
# Processing Record 33 of Set 2 | mar del plata
# Processing Record 34 of Set 2 | labutta
# City not found. Skipping...
# Processing Record 35 of Set 2 | krasnorechenskiy
# Processing Record 36 of Set 2 | san juan
# Processing Record 37 of Set 2 | constantine
# Processing Record 38 of Set 2 | lagoa
# Processing Record 39 of Set 2 | kodiak
# Processing Record 40 of Set 2 | tiksi
# Processing Record 41 of Set 2 | ostrovnoy
# Processing Record 42 of Set 2 | kavieng
# Processing Record 43 of Set 2 | moyale
# Processing Record 44 of Set 2 | bethel
# Processing Record 45 of Set 2 | bontang
# Processing Record 46 of Set 2 | fort saint john
# City not found. Skipping...
# Processing Record 47 of Set 2 | vostok
# Processing Record 48 of Set 2 | talaya
# Processing Record 49 of Set 2 | avarua
# Processing Record 50 of Set 2 | butaritari
# Processing Record 1 of Set 3 | beira
# Processing Record 2 of Set 3 | umm kaddadah
# Processing Record 3 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 3 | yeppoon
# Processing Record 5 of Set 3 | hasaki
# Processing Record 6 of Set 3 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 7 of Set 3 | narsaq
# Processing Record 8 of Set 3 | ahipara
# Processing Record 9 of Set 3 | mayo
# Processing Record 10 of Set 3 | savinka
# Processing Record 11 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 12 of Set 3 | kathmandu
# Processing Record 13 of Set 3 | stykkisholmur
# Processing Record 14 of Set 3 | banjar
# Processing Record 15 of Set 3 | tigil
# Processing Record 16 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 3 | fortuna
# Processing Record 18 of Set 3 | puerto ayora
# Processing Record 19 of Set 3 | kruisfontein
# Processing Record 20 of Set 3 | hami
# Processing Record 21 of Set 3 | mabaruma
# Processing Record 22 of Set 3 | malakal
# Processing Record 23 of Set 3 | thompson
# Processing Record 24 of Set 3 | rio grande
# Processing Record 25 of Set 3 | lisala
# Processing Record 26 of Set 3 | magadi
# Processing Record 27 of Set 3 | san jose
# Processing Record 28 of Set 3 | camocim
# Processing Record 29 of Set 3 | marechal candido rondon
# Processing Record 30 of Set 3 | cherskiy
# Processing Record 31 of Set 3 | pangnirtung
# Processing Record 32 of Set 3 | cap malheureux
# Processing Record 33 of Set 3 | portland
# Processing Record 34 of Set 3 | birao
# Processing Record 35 of Set 3 | broken hill
# Processing Record 36 of Set 3 | sola
# Processing Record 37 of Set 3 | arraial do cabo
# Processing Record 38 of Set 3 | teya
# Processing Record 39 of Set 3 | yabassi
# Processing Record 40 of Set 3 | mount isa
# Processing Record 41 of Set 3 | hauterive
# Processing Record 42 of Set 3 | port elizabeth
# Processing Record 43 of Set 3 | martapura
# Processing Record 44 of Set 3 | te anau
# Processing Record 45 of Set 3 | shanghai
# Processing Record 46 of Set 3 | lompoc
# Processing Record 47 of Set 3 | rocha
# Processing Record 48 of Set 3 | puerto penasco
# Processing Record 49 of Set 3 | barrow
# Processing Record 50 of Set 3 | were ilu
# Processing Record 1 of Set 4 | mogadishu
# Processing Record 2 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 4 | cabo san lucas
# Processing Record 4 of Set 4 | touros
# Processing Record 5 of Set 4 | contamana
# Processing Record 6 of Set 4 | tuktoyaktuk
# Processing Record 7 of Set 4 | sao filipe
# Processing Record 8 of Set 4 | sattahip
# Processing Record 9 of Set 4 | nanakuli
# Processing Record 10 of Set 4 | palmer
# Processing Record 11 of Set 4 | elizabeth city
# Processing Record 12 of Set 4 | pirapozinho
# Processing Record 13 of Set 4 | rawson
# Processing Record 14 of Set 4 | shingu
# Processing Record 15 of Set 4 | labuan
# Processing Record 16 of Set 4 | rio gallegos
# Processing Record 17 of Set 4 | sechura
# Processing Record 18 of Set 4 | saint-denis
# Processing Record 19 of Set 4 | labytnangi
# Processing Record 20 of Set 4 | cockburn town
# Processing Record 21 of Set 4 | teguldet
# Processing Record 22 of Set 4 | tamandare
# Processing Record 23 of Set 4 | necochea
# Processing Record 24 of Set 4 | tasiilaq
# Processing Record 25 of Set 4 | esperance
# Processing Record 26 of Set 4 | beloha
# Processing Record 27 of Set 4 | ozernovskiy
# Processing Record 28 of Set 4 | charlestown
# Processing Record 29 of Set 4 | vao
# Processing Record 30 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 4 | washougal
# Processing Record 32 of Set 4 | pisco
# Processing Record 33 of Set 4 | jumla
# Processing Record 34 of Set 4 | castro
# Processing Record 35 of Set 4 | praia da vitoria
# Processing Record 36 of Set 4 | busselton
# Processing Record 37 of Set 4 | jawar
# Processing Record 38 of Set 4 | madridejos
# Processing Record 39 of Set 4 | naze
# Processing Record 40 of Set 4 | batticaloa
# Processing Record 41 of Set 4 | sistranda
# Processing Record 42 of Set 4 | saint anthony
# Processing Record 43 of Set 4 | waingapu
# Processing Record 44 of Set 4 | bengkulu
# Processing Record 45 of Set 4 | ribeira grande
# Processing Record 46 of Set 4 | mildura
# Processing Record 47 of Set 4 | dawlatabad
# Processing Record 48 of Set 4 | ponta do sol
# Processing Record 49 of Set 4 | mbandaka
# Processing Record 50 of Set 4 | torbay
# Processing Record 1 of Set 5 | itoman
# Processing Record 2 of Set 5 | hastings
# Processing Record 3 of Set 5 | aksarka
# Processing Record 4 of Set 5 | bedford
# Processing Record 5 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 5 | kabo
# Processing Record 7 of Set 5 | vestmannaeyjar
# Processing Record 8 of Set 5 | hambantota
# Processing Record 9 of Set 5 | moba
# Processing Record 10 of Set 5 | danjiangkou
# Processing Record 11 of Set 5 | carnarvon
# Processing Record 12 of Set 5 | aitape
# Processing Record 13 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 5 | qui nhon
# Processing Record 15 of Set 5 | ancud
# Processing Record 16 of Set 5 | saint-joseph
# Processing Record 17 of Set 5 | masaka
# Processing Record 18 of Set 5 | kaz
# Processing Record 19 of Set 5 | lusambo
# Processing Record 20 of Set 5 | amahai
# Processing Record 21 of Set 5 | peleduy
# Processing Record 22 of Set 5 | tecoanapa
# Processing Record 23 of Set 5 | toamasina
# Processing Record 24 of Set 5 | mount gambier
# Processing Record 25 of Set 5 | vestmanna
# Processing Record 26 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 5 | upernavik
# Processing Record 28 of Set 5 | hwange
# Processing Record 29 of Set 5 | scottsburgh
# City not found. Skipping...
# Processing Record 30 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 5 | xining
# Processing Record 32 of Set 5 | kurumkan
# Processing Record 33 of Set 5 | nortelandia
# Processing Record 34 of Set 5 | nhulunbuy
# Processing Record 35 of Set 5 | belyy yar
# Processing Record 36 of Set 5 | ovre ardal
# Processing Record 37 of Set 5 | xaxim
# Processing Record 38 of Set 5 | fairbanks
# Processing Record 39 of Set 5 | tema
# Processing Record 40 of Set 5 | pontian kecil
# Processing Record 41 of Set 5 | sivas
# Processing Record 42 of Set 5 | celestun
# Processing Record 43 of Set 5 | kaitangata
# Processing Record 44 of Set 5 | avera
# Processing Record 45 of Set 5 | sao felix do xingu
# Processing Record 46 of Set 5 | clyde river
# Processing Record 47 of Set 5 | nabire
# Processing Record 48 of Set 5 | souillac
# Processing Record 49 of Set 5 | kerki
# City not found. Skipping...
# Processing Record 50 of Set 5 | laramie
# Processing Record 1 of Set 6 | saint-philippe
# Processing Record 2 of Set 6 | sinjai
# Processing Record 3 of Set 6 | victor harbor
# Processing Record 4 of Set 6 | najran
# Processing Record 5 of Set 6 | port augusta
# Processing Record 6 of Set 6 | saint-pierre
# Processing Record 7 of Set 6 | swidnica
# Processing Record 8 of Set 6 | samarai
# Processing Record 9 of Set 6 | norman wells
# Processing Record 10 of Set 6 | keokuk
# Processing Record 11 of Set 6 | fare
# Processing Record 12 of Set 6 | katsuura
# Processing Record 13 of Set 6 | batemans bay
# Processing Record 14 of Set 6 | asyut
# Processing Record 15 of Set 6 | acari
# Processing Record 16 of Set 6 | lavrentiya
# Processing Record 17 of Set 6 | yulara
# Processing Record 18 of Set 6 | bilibino
# Processing Record 19 of Set 6 | goalpara
# Processing Record 20 of Set 6 | hobe sound
# Processing Record 21 of Set 6 | plettenberg bay
# Processing Record 22 of Set 6 | huarmey
# Processing Record 23 of Set 6 | kolokani
# Processing Record 24 of Set 6 | kayerkan
# Processing Record 25 of Set 6 | san quintin
# Processing Record 26 of Set 6 | chegdomyn
# Processing Record 27 of Set 6 | minab
# Processing Record 28 of Set 6 | luganville
# Processing Record 29 of Set 6 | ituni
# City not found. Skipping...
# Processing Record 30 of Set 6 | maua
# Processing Record 31 of Set 6 | cayenne
# Processing Record 32 of Set 6 | codrington
# Processing Record 33 of Set 6 | roma
# Processing Record 34 of Set 6 | grand-lahou
# Processing Record 35 of Set 6 | kloulklubed
# Processing Record 36 of Set 6 | gotemba
# Processing Record 37 of Set 6 | bayevo
# Processing Record 38 of Set 6 | chapais
# Processing Record 39 of Set 6 | sieradz
# Processing Record 40 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 41 of Set 6 | xichang
# Processing Record 42 of Set 6 | vanimo
# Processing Record 43 of Set 6 | aklavik
# Processing Record 44 of Set 6 | camacha
# Processing Record 45 of Set 6 | duz
# City not found. Skipping...
# Processing Record 46 of Set 6 | walvis bay
# Processing Record 47 of Set 6 | pabbi
# Processing Record 48 of Set 6 | manta
# Processing Record 49 of Set 6 | dibaya
# City not found. Skipping...
# Processing Record 50 of Set 6 | byron bay
# Processing Record 1 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 2 of Set 7 | colombo
# Processing Record 3 of Set 7 | akureyri
# Processing Record 4 of Set 7 | dzilam gonzalez
# Processing Record 5 of Set 7 | coquimbo
# Processing Record 6 of Set 7 | meulaboh
# Processing Record 7 of Set 7 | faya
# Processing Record 8 of Set 7 | carlsbad
# Processing Record 9 of Set 7 | muleba
# Processing Record 10 of Set 7 | varhaug
# Processing Record 11 of Set 7 | tshane
# Processing Record 12 of Set 7 | port keats
# Processing Record 13 of Set 7 | roebourne
# Processing Record 14 of Set 7 | kenai
# Processing Record 15 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 7 | dicabisagan
# Processing Record 17 of Set 7 | half moon bay
# Processing Record 18 of Set 7 | phalombe
# Processing Record 19 of Set 7 | bredasdorp
# Processing Record 20 of Set 7 | makakilo city
# Processing Record 21 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 22 of Set 7 | nikolskoye
# Processing Record 23 of Set 7 | kutum
# Processing Record 24 of Set 7 | havre-saint-pierre
# Processing Record 25 of Set 7 | bemidji
# Processing Record 26 of Set 7 | maloy
# Processing Record 27 of Set 7 | pecos
# Processing Record 28 of Set 7 | itaporanga
# Processing Record 29 of Set 7 | northam
# Processing Record 30 of Set 7 | klaksvik
# Processing Record 31 of Set 7 | neiafu
# Processing Record 32 of Set 7 | sorland
# Processing Record 33 of Set 7 | bambous virieux
# Processing Record 34 of Set 7 | namatanai
# Processing Record 35 of Set 7 | bonavista
# Processing Record 36 of Set 7 | rong kwang
# Processing Record 37 of Set 7 | okato
# Processing Record 38 of Set 7 | hanzhong
# Processing Record 39 of Set 7 | dalbandin
# Processing Record 40 of Set 7 | qasigiannguit
# Processing Record 41 of Set 7 | wagar
# Processing Record 42 of Set 7 | strai
# Processing Record 43 of Set 7 | eldorado
# Processing Record 44 of Set 7 | kropotkin
# Processing Record 45 of Set 7 | port-gentil
# Processing Record 46 of Set 7 | wanning
# Processing Record 47 of Set 7 | ust-tsilma
# Processing Record 48 of Set 7 | pimentel
# Processing Record 49 of Set 7 | gold coast
# Processing Record 50 of Set 7 | zanesville
# Processing Record 1 of Set 8 | broome
# Processing Record 2 of Set 8 | sayat
# Processing Record 3 of Set 8 | storforshei
# Processing Record 4 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 8 | plyussa
# Processing Record 6 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 8 | kaeo
# Processing Record 8 of Set 8 | grand gaube
# Processing Record 9 of Set 8 | parkes
# Processing Record 10 of Set 8 | mumford
# Processing Record 11 of Set 8 | mehamn
# Processing Record 12 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 13 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 14 of Set 8 | novaya mayna
# Processing Record 15 of Set 8 | mersing
# Processing Record 16 of Set 8 | namibe
# Processing Record 17 of Set 8 | shimoda
# Processing Record 18 of Set 8 | isangel
# Processing Record 19 of Set 8 | hoquiam
# Processing Record 20 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 21 of Set 8 | sorong
# Processing Record 22 of Set 8 | deqing
# Processing Record 23 of Set 8 | kulhudhuffushi
# Processing Record 24 of Set 8 | kysyl-syr
# Processing Record 25 of Set 8 | dunnville
# Processing Record 26 of Set 8 | nemuro
# Processing Record 27 of Set 8 | tilichiki
# Processing Record 28 of Set 8 | angoche
# Processing Record 29 of Set 8 | san patricio
# Processing Record 30 of Set 8 | moose factory
# Processing Record 31 of Set 8 | margate
# Processing Record 32 of Set 8 | havelock
# Processing Record 33 of Set 8 | nanortalik
# Processing Record 34 of Set 8 | gunnedah
# Processing Record 35 of Set 8 | karauzyak
# City not found. Skipping...
# Processing Record 36 of Set 8 | praia
# Processing Record 37 of Set 8 | santa maria
# Processing Record 38 of Set 8 | kieta
# Processing Record 39 of Set 8 | kosh-agach
# Processing Record 40 of Set 8 | alofi
# Processing Record 41 of Set 8 | vila velha
# Processing Record 42 of Set 8 | tsaratanana
# Processing Record 43 of Set 8 | nizhniy tsasuchey
# Processing Record 44 of Set 8 | coxim
# Processing Record 45 of Set 8 | persianovskiy
# Processing Record 46 of Set 8 | ucluelet
# Processing Record 47 of Set 8 | labuhan
# Processing Record 48 of Set 8 | krasnoturansk
# Processing Record 49 of Set 8 | deputatskiy
# Processing Record 50 of Set 8 | jishou
# Processing Record 1 of Set 9 | limpapa
# Processing Record 2 of Set 9 | sitka
# Processing Record 3 of Set 9 | sao joao da barra
# Processing Record 4 of Set 9 | opuwo
# Processing Record 5 of Set 9 | vardo
# Processing Record 6 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 7 of Set 9 | brae
# Processing Record 8 of Set 9 | nara
# Processing Record 9 of Set 9 | kroya
# Processing Record 10 of Set 9 | pau brasil
# Processing Record 11 of Set 9 | nuevo progreso
# Processing Record 12 of Set 9 | dzhebariki-khaya
# Processing Record 13 of Set 9 | paamiut
# Processing Record 14 of Set 9 | coihaique
# Processing Record 15 of Set 9 | mackay
# Processing Record 16 of Set 9 | kungalv
# Processing Record 17 of Set 9 | kondinskoye
# Processing Record 18 of Set 9 | dembi dolo
# Processing Record 19 of Set 9 | san antonio
# Processing Record 20 of Set 9 | turayf
# Processing Record 21 of Set 9 | auki
# Processing Record 22 of Set 9 | colonia
# Processing Record 23 of Set 9 | rio verde de mato grosso
# Processing Record 24 of Set 9 | dingle
# Processing Record 25 of Set 9 | pacho
# Processing Record 26 of Set 9 | oil city
# Processing Record 27 of Set 9 | amapa
# Processing Record 28 of Set 9 | blagoveshchenka
# Processing Record 29 of Set 9 | los llanos de aridane
# Processing Record 30 of Set 9 | weinan
# Processing Record 31 of Set 9 | veraval
# Processing Record 32 of Set 9 | staraya toropa
# Processing Record 33 of Set 9 | zhigansk
# Processing Record 34 of Set 9 | santa cruz
# Processing Record 35 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 9 | santa rosa
# Processing Record 37 of Set 9 | shaoguan
# Processing Record 38 of Set 9 | portpatrick
# City not found. Skipping...
# Processing Record 39 of Set 9 | storsteinnes
# Processing Record 40 of Set 9 | ahuimanu
# Processing Record 41 of Set 9 | dali
# Processing Record 42 of Set 9 | burriana
# Processing Record 43 of Set 9 | vinh
# Processing Record 44 of Set 9 | omboue
# Processing Record 45 of Set 9 | halifax
# Processing Record 46 of Set 9 | khunti
# Processing Record 47 of Set 9 | upata
# Processing Record 48 of Set 9 | asau
# Processing Record 49 of Set 9 | yuxia
# Processing Record 50 of Set 9 | honningsvag
# Processing Record 1 of Set 10 | inhuma
# Processing Record 2 of Set 10 | teluk nibung
# Processing Record 3 of Set 10 | benito juarez
# Processing Record 4 of Set 10 | nanuque
# Processing Record 5 of Set 10 | katherine
# Processing Record 6 of Set 10 | verkhoyansk
# Processing Record 7 of Set 10 | san carlos de bariloche
# Processing Record 8 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 10 | macenta
# Processing Record 10 of Set 10 | lasa
# Processing Record 11 of Set 10 | eatonton
# Processing Record 12 of Set 10 | zunyi
# Processing Record 13 of Set 10 | westport
# Processing Record 14 of Set 10 | talcahuano
# Processing Record 15 of Set 10 | lagos
# Processing Record 16 of Set 10 | kavaratti
# Processing Record 17 of Set 10 | leningradskiy
# Processing Record 18 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 19 of Set 10 | along
# Processing Record 20 of Set 10 | gainesville
# Processing Record 21 of Set 10 | saldanha
# Processing Record 22 of Set 10 | concarneau
# Processing Record 23 of Set 10 | reni
# Processing Record 24 of Set 10 | cody
# Processing Record 25 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 26 of Set 10 | puerto del rosario
# Processing Record 27 of Set 10 | hamilton
# Processing Record 28 of Set 10 | santona
# Processing Record 29 of Set 10 | thinadhoo
# Processing Record 30 of Set 10 | abeche
# Processing Record 31 of Set 10 | ngunguru
# Processing Record 32 of Set 10 | pacifica
# Processing Record 33 of Set 10 | lufilufi
# Processing Record 34 of Set 10 | diamantino
# Processing Record 35 of Set 10 | astana
# Processing Record 36 of Set 10 | bandarbeyla
# Processing Record 37 of Set 10 | ostersund
# Processing Record 38 of Set 10 | giyani
# Processing Record 39 of Set 10 | gravdal
# Processing Record 40 of Set 10 | nouadhibou
# Processing Record 41 of Set 10 | uni
# Processing Record 42 of Set 10 | oltu
# Processing Record 43 of Set 10 | finschhafen
# Processing Record 44 of Set 10 | kamaishi
# Processing Record 45 of Set 10 | colac
# Processing Record 46 of Set 10 | ewa beach
# Processing Record 47 of Set 10 | amot
# Processing Record 48 of Set 10 | morondava
# Processing Record 49 of Set 10 | port hardy
# Processing Record 50 of Set 10 | shelburne
# Processing Record 1 of Set 11 | uzhur
# Processing Record 2 of Set 11 | victoria
# Processing Record 3 of Set 11 | pajapan
# Processing Record 4 of Set 11 | longyearbyen
# Processing Record 5 of Set 11 | sorgun
# Processing Record 6 of Set 11 | armenis
# Processing Record 7 of Set 11 | coracao de jesus
# Processing Record 8 of Set 11 | port moresby
# Processing Record 9 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 11 | prince rupert
# Processing Record 11 of Set 11 | maceio
# Processing Record 12 of Set 11 | santa catarina de tepehuanes
# Processing Record 13 of Set 11 | bridlington
# Processing Record 14 of Set 11 | san francisco
# Processing Record 15 of Set 11 | iqaluit
# Processing Record 16 of Set 11 | watsa
# Processing Record 17 of Set 11 | puerto quijarro
# Processing Record 18 of Set 11 | nome
# Processing Record 19 of Set 11 | furano
# Processing Record 20 of Set 11 | san cristobal
# Processing Record 21 of Set 11 | preobrazheniye
# Processing Record 22 of Set 11 | fairview
# Processing Record 23 of Set 11 | biltine
# Processing Record 24 of Set 11 | araouane
# Processing Record 25 of Set 11 | jining
# Processing Record 26 of Set 11 | chara
# Processing Record 27 of Set 11 | vila franca do campo
# Processing Record 28 of Set 11 | stuttgart
# Processing Record 29 of Set 11 | mayya
# Processing Record 30 of Set 11 | ovsyanka
# Processing Record 31 of Set 11 | hoi an
# Processing Record 32 of Set 11 | mandalgovi
# Processing Record 33 of Set 11 | freising
# Processing Record 34 of Set 11 | emmett
# Processing Record 35 of Set 11 | manggar
# Processing Record 36 of Set 11 | kampong chhnang
# Processing Record 37 of Set 11 | paramonga
# Processing Record 38 of Set 11 | maues
# Processing Record 39 of Set 11 | mahibadhoo
# Processing Record 40 of Set 11 | bathsheba
# Processing Record 41 of Set 11 | burevestnik
# Processing Record 42 of Set 11 | olafsvik
# Processing Record 43 of Set 11 | tomatlan
# Processing Record 44 of Set 11 | cuiaba
# Processing Record 45 of Set 11 | fethiye
# Processing Record 46 of Set 11 | mandera
# Processing Record 47 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 48 of Set 11 | akdepe
# Processing Record 49 of Set 11 | bartica
# Processing Record 50 of Set 11 | quatre cocos
# Processing Record 1 of Set 12 | kidal
# Processing Record 2 of Set 12 | bulolo
# Processing Record 3 of Set 12 | yanam
# Processing Record 4 of Set 12 | bose
# Processing Record 5 of Set 12 | chirongui
# Processing Record 6 of Set 12 | manjeshwar
# Processing Record 7 of Set 12 | fontem
# Processing Record 8 of Set 12 | invermere
# Processing Record 9 of Set 12 | butembo
# Processing Record 10 of Set 12 | nioro
# Processing Record 11 of Set 12 | viedma
# Processing Record 12 of Set 12 | idukki
# Processing Record 13 of Set 12 | svetlyy
# Processing Record 14 of Set 12 | lakatoro
# Processing Record 15 of Set 12 | ocean city
# Processing Record 16 of Set 12 | maniitsoq
# Processing Record 17 of Set 12 | mangrol
# Processing Record 18 of Set 12 | bardiyah
# Processing Record 19 of Set 12 | havoysund
# Processing Record 20 of Set 12 | pendleton
# Processing Record 21 of Set 12 | mecca
# Processing Record 22 of Set 12 | pringsewu
# Processing Record 23 of Set 12 | windhoek
# Processing Record 24 of Set 12 | jiwani
# Processing Record 25 of Set 12 | yining
# Processing Record 26 of Set 12 | srinivaspur
# Processing Record 27 of Set 12 | qaqortoq
# Processing Record 28 of Set 12 | shuangyang
# Processing Record 29 of Set 12 | angoram
# Processing Record 30 of Set 12 | airai
# Processing Record 31 of Set 12 | fomboni
# Processing Record 32 of Set 12 | bambanglipuro
# Processing Record 33 of Set 12 | okhotsk
# Processing Record 34 of Set 12 | disna
# Processing Record 35 of Set 12 | buraydah
# Processing Record 36 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 37 of Set 12 | korla
# Processing Record 38 of Set 12 | hovd
# Processing Record 39 of Set 12 | the valley
# Processing Record 40 of Set 12 | jawhar
# Processing Record 41 of Set 12 | erenhot
# Processing Record 42 of Set 12 | bubaque
# Processing Record 43 of Set 12 | kununurra
# Processing Record 44 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 45 of Set 12 | whitehorse
# Processing Record 46 of Set 12 | ossora
# Processing Record 47 of Set 12 | vrangel
# Processing Record 48 of Set 12 | mandan
# Processing Record 49 of Set 12 | aleksandrov gay
# Processing Record 50 of Set 12 | rosita
# Processing Record 1 of Set 13 | vanavara
# Processing Record 2 of Set 13 | bosaso
# Processing Record 3 of Set 13 | kijang
# Processing Record 4 of Set 13 | sambava
# Processing Record 5 of Set 13 | umarkot
# Processing Record 6 of Set 13 | grand forks
# Processing Record 7 of Set 13 | uddevalla
# Processing Record 8 of Set 13 | morlaix
# Processing Record 9 of Set 13 | ponta delgada
# Processing Record 10 of Set 13 | atasu
# Processing Record 11 of Set 13 | cabedelo
# Processing Record 12 of Set 13 | ous
# Processing Record 13 of Set 13 | warrington
# Processing Record 14 of Set 13 | syracuse
# Processing Record 15 of Set 13 | carrollton
# Processing Record 16 of Set 13 | bathurst
# Processing Record 17 of Set 13 | asfi
# Processing Record 18 of Set 13 | temerloh
# Processing Record 19 of Set 13 | conceicao do araguaia
# Processing Record 20 of Set 13 | kamenka
# Processing Record 21 of Set 13 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 22 of Set 13 | sinnamary
# Processing Record 23 of Set 13 | vikarabad
# Processing Record 24 of Set 13 | yomitan
# City not found. Skipping...
# Processing Record 25 of Set 13 | kurilsk
# Processing Record 26 of Set 13 | riyadh
# Processing Record 27 of Set 13 | heidenau
# Processing Record 28 of Set 13 | tranas
# Processing Record 29 of Set 13 | miragoane
# Processing Record 30 of Set 13 | hermiston
# Processing Record 31 of Set 13 | atambua
# Processing Record 32 of Set 13 | atar
# Processing Record 33 of Set 13 | neuquen
# Processing Record 34 of Set 13 | muros
# Processing Record 35 of Set 13 | san andres del rabanedo
# Processing Record 36 of Set 13 | kushima
# Processing Record 37 of Set 13 | axim
# Processing Record 38 of Set 13 | cidreira
# Processing Record 39 of Set 13 | khor
# Processing Record 40 of Set 13 | luwuk
# Processing Record 41 of Set 13 | yertsevo
# Processing Record 42 of Set 13 | wa
# City not found. Skipping...
# Processing Record 43 of Set 13 | petawawa
# Processing Record 44 of Set 13 | plainview
# Processing Record 45 of Set 13 | matinha
# Processing Record 46 of Set 13 | hirara
# Processing Record 47 of Set 13 | san policarpo
# Processing Record 48 of Set 13 | hofn
# Processing Record 49 of Set 13 | liku
# Processing Record 50 of Set 13 | dunedin
# Processing Record 1 of Set 14 | shache
# Processing Record 2 of Set 14 | geraldton
# Processing Record 3 of Set 14 | akyab
# Processing Record 4 of Set 14 | zhanatas
# City not found. Skipping...
# Processing Record 5 of Set 14 | port lincoln
# Processing Record 6 of Set 14 | khurba
# Processing Record 7 of Set 14 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 14 | skalistyy
# City not found. Skipping...
# Processing Record 9 of Set 14 | vigrestad
# Processing Record 10 of Set 14 | villazon
# Processing Record 11 of Set 14 | tugulym
# Processing Record 12 of Set 14 | nadvoitsy
# Processing Record 13 of Set 14 | sibolga
# Processing Record 14 of Set 14 | port hedland
# Processing Record 15 of Set 14 | road town
# Processing Record 16 of Set 14 | edson
# Processing Record 17 of Set 14 | yuzhne
# Processing Record 18 of Set 14 | antipino
# Processing Record 19 of Set 14 | baglan
# Processing Record 20 of Set 14 | aksu
# Processing Record 21 of Set 14 | abu dhabi
# Processing Record 22 of Set 14 | manyana
# Processing Record 23 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 24 of Set 14 | seoul
# Processing Record 25 of Set 14 | morant bay
# Processing Record 26 of Set 14 | north vanlaiphai
# Processing Record 27 of Set 14 | cardston
# Processing Record 28 of Set 14 | spassk-ryazanskiy
# Processing Record 29 of Set 14 | ternate
# Processing Record 30 of Set 14 | kebemer
# City not found. Skipping...
# Processing Record 31 of Set 14 | basco
# Processing Record 32 of Set 14 | albury
# Processing Record 33 of Set 14 | college
# Processing Record 34 of Set 14 | nejdek
# Processing Record 35 of Set 14 | sakaiminato
# Processing Record 36 of Set 14 | vadlapudi
# Processing Record 37 of Set 14 | carbondale
# Processing Record 38 of Set 14 | koutsouras
# Processing Record 39 of Set 14 | darnah
# Processing Record 40 of Set 14 | yialos
# City not found. Skipping...
# Processing Record 41 of Set 14 | harlingen
# Processing Record 42 of Set 14 | moron
# Processing Record 43 of Set 14 | beringovskiy
# Processing Record 44 of Set 14 | yuanping
# Processing Record 45 of Set 14 | tocopilla
# Processing Record 46 of Set 14 | ambodifototra
# City not found. Skipping...
# Processing Record 47 of Set 14 | dergachi
# Processing Record 48 of Set 14 | burica
# City not found. Skipping...
# Processing Record 49 of Set 14 | taksimo
# Processing Record 50 of Set 14 | verkhnyaya inta
# Processing Record 1 of Set 15 | gazojak
# Processing Record 2 of Set 15 | sept-iles
# Processing Record 3 of Set 15 | portobelo
# Processing Record 4 of Set 15 | pennagaram
# Processing Record 5 of Set 15 | san borja
# Processing Record 6 of Set 15 | kalakamati
# Processing Record 7 of Set 15 | bronnoysund
# Processing Record 8 of Set 15 | graaff-reinet
# Processing Record 9 of Set 15 | herran
# Processing Record 10 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 11 of Set 15 | clifton
# Processing Record 12 of Set 15 | la ronge
# Processing Record 13 of Set 15 | visconde do rio branco
# Processing Record 14 of Set 15 | la romana
# Processing Record 15 of Set 15 | beyneu
# Processing Record 16 of Set 15 | deh rawud
# City not found. Skipping...
# Processing Record 17 of Set 15 | sychevka
# Processing Record 18 of Set 15 | gizo
# Processing Record 19 of Set 15 | alice springs
# Processing Record 20 of Set 15 | nacozari
# Processing Record 21 of Set 15 | tunduru
# City not found. Skipping...
# Processing Record 22 of Set 15 | sur
# Processing Record 23 of Set 15 | koscierzyna
# Processing Record 24 of Set 15 | falun
# Processing Record 25 of Set 15 | bow island
# Processing Record 26 of Set 15 | suntar
# Processing Record 27 of Set 15 | marystown
# Processing Record 28 of Set 15 | gat
# Processing Record 29 of Set 15 | tazovskiy
# Processing Record 30 of Set 15 | kharagauli
# Processing Record 31 of Set 15 | odweyne
# Processing Record 32 of Set 15 | devils lake
# Processing Record 33 of Set 15 | xuddur
# Processing Record 34 of Set 15 | haines junction
# Processing Record 35 of Set 15 | carauari
# Processing Record 36 of Set 15 | mao
# Processing Record 37 of Set 15 | benguela
# Processing Record 38 of Set 15 | taburi
# City not found. Skipping...
# Processing Record 39 of Set 15 | lajedo
# Processing Record 40 of Set 15 | cuencame
# Processing Record 41 of Set 15 | termoli
# Processing Record 42 of Set 15 | rognan
# Processing Record 43 of Set 15 | timra
# Processing Record 44 of Set 15 | saint-augustin
# Processing Record 45 of Set 15 | misratah
# Processing Record 46 of Set 15 | kirn
# Processing Record 47 of Set 15 | mugur-aksy
# Processing Record 48 of Set 15 | cabra
# Processing Record 49 of Set 15 | sobolevo
# Processing Record 50 of Set 15 | husavik
# Processing Record 1 of Set 16 | ust-koksa
# Processing Record 2 of Set 16 | tallahassee
# Processing Record 3 of Set 16 | dalby
# Processing Record 4 of Set 16 | mazatlan
# Processing Record 5 of Set 16 | komsomolskiy
# Processing Record 6 of Set 16 | doume
# Processing Record 7 of Set 16 | mafinga
# Processing Record 8 of Set 16 | chumikan
# Processing Record 9 of Set 16 | krasnoselkup
# Processing Record 10 of Set 16 | greenwood
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Number of cities in the city_data array of dictionaries
len(city_data)
# Out:
# 705

# %% [markdown]
# ## Create a pandas DataFrame

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Aquiraz  -3.9014  -38.3911     82.49        66          89
# 1       Yellowknife  62.4560 -114.3525     10.92        85         100
# 2           Ushuaia -54.8000  -68.3000     55.02        53          40
# 3            Albany  42.6001  -73.9662     52.45        34           0
# 4        Champerico  14.3000  -91.9167     84.74        70          99
# 5           Rikitea -23.1203 -134.9692     75.09        90          77
# 6            Faanui -16.4833 -151.7500     78.39        70          93
# 7  Verkhnyaya Toyma  62.2349   44.9985     33.40        99         100
# 8           Mataura -46.1927  168.8643     55.18        76          96
# 9       Port Alfred -33.5906   26.8910     65.17        91          56
#
#    Wind Speed Country Current Description                 Date
# 0       10.13      BR     overcast clouds  2022-11-08 20:27:32
# 1        3.44      CA          light snow  2022-11-08 20:27:32
# 2       23.02      AR    scattered clouds  2022-11-08 20:24:11
# 3        1.01      US           clear sky  2022-11-08 20:24:16
# 4        3.51      GT          light rain  2022-11-08 20:27:33
# 5       15.90      PF          light rain  2022-11-08 20:27:34
# 6        9.95      PF     overcast clouds  2022-11-08 20:27:34
# 7        3.20      RU     overcast clouds  2022-11-08 20:27:35
# 8        2.93      NZ     overcast clouds  2022-11-08 20:27:35
# 9        7.67      ZA       broken clouds  2022-11-08 20:27:36

# %% [markdown]
# ## Creating the CSV File

# %%
# Create the output File (CSV)
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# Show Record Count
city_data_df.count()
# Out:
# City                   705
# Lat                    705
# Lng                    705
# Max Temp               705
# Humidity               705
# Cloudiness             705
# Wind Speed             705
# Country                705
# Current Description    705
# Date                   705
# dtype: int64
